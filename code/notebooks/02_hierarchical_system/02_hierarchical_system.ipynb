# %%
import pathlib
import sys
sys.path.insert(0, str(pathlib.Path("../..").absolute()))
from IPython.display import display, clear_output, Image
from environment import MultiStageEnv
from computation_sim.system import SystemDrawer

# %%
# We have a discrete time system with a time step of 10ms
dt = 10 


# Set-up some default parameters
params = {
    "environment" : {
        "dt": dt, 
        "cost_input": 0.01, # Regularization cost for input
        "cost_message_loss": 1.0, # Primary goal: Minimize message loss
        "cost_output_time": 0.1 / 100.0, # Secondary goal: Minimize age of oldest information in the output
    }
}
env = MultiStageEnv(**params["environment"])

drawer = SystemDrawer()
drawer.build(env.system.node_graph)
drawer.fw.update_layout(height=800)
clear_output(wait=True)
display(drawer.fw)
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'none',
#               'line': {'color': '#888', 'width': 1.0},
#               'mode': 'lines',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f8165c7e-5a72-4521-afa1-d0293f9bd6f2',
#               'x': [-0.4303030303030303, -0.2484848484848485, None, ...,
#                     0.4787878787878788, 0.6606060606060606, None],
#               'y': [-0.9090909090909092, -0.9090909090909092, None, ...,
#                     0.18181818181818182, 0.09090909090909091, None]},
#              {'hovertext': [num_messages = 0, num_messages = 0, num_messages = 0,
#                             num_messages = 0, num_messages = 0, num_messages = 0, ,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = False<br>t_start_age = 0.0, ,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, , is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, , is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = False<br>t_start_age = 0.0, ,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, , is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, , is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = False<br>t_start_age = 0.0, ,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, , is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, , is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = False<br>t_start_age = 0.0, ,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = True<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_busy = False<br>t_start_age = 0.0,
#                             is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average =
#                             0.0<br>, is_occupied = 0.0<br>msg.age_oldest =
#                             0.0<br>msg.age_youngest = 0.0<br>msg.age_average = 0.0],
#               'marker': {'color': [darkgrey, darkgrey, darkgrey, darkgrey,
#                                    darkgrey, darkgrey, floralwhite, darkgreen,
#                                    darkred, darkgreen, darkgreen, floralwhite,
#                                    darkgreen, darkred, darkgreen, floralwhite,
#                                    darkgreen, darkred, darkgreen, floralwhite,
#                                    darkgreen, darkred, darkgreen, darkgreen,
#                                    floralwhite, darkgreen, darkred, darkgreen,
#                                    floralwhite, darkgreen, darkred, darkgreen,
#                                    floralwhite, darkgreen, darkred, darkgreen,
#                                    darkgreen, floralwhite, darkgreen, darkred,
#                                    darkgreen, floralwhite, darkgreen, darkred,
#                                    darkgreen, floralwhite, darkgreen, darkred,
#                                    darkgreen, darkgreen, floralwhite, darkgreen,
#                                    darkred, darkgreen, darkgreen, darkgreen,
#                                    darkgreen, darkgreen, darkgreen, dimgrey],
#                          'coloraxis': 'coloraxis',
#                          'line': {'width': 2},
#                          'showscale': False,
#                          'size': 20,
#                          'symbol': [triangle-down, triangle-down, triangle-down,
#                                     triangle-down, triangle-down, triangle-down,
#                                     triangle-up, square, square, square, square,
#                                     triangle-up, square, square, square, triangle-
#                                     up, square, square, square, triangle-up,
#                                     square, square, square, square, triangle-up,
#                                     square, square, square, triangle-up, square,
#                                     square, square, triangle-up, square, square,
#                                     square, square, triangle-up, square, square,
#                                     square, triangle-up, square, square, square,
#                                     triangle-up, square, square, square, square,
#                                     triangle-up, square, square, square, square,
#                                     square, square, square, square, circle]},
#               'mode': 'markers+text',
#               'showlegend': False,
#               'text': [SENSOR_BUFFER_LOST, SENSOR_COMPUTE_LOST,
#                        SENSOR_COMPUTE_BUFFER_LOST, EDGE_COMPUTE_LOST,
#                        EDGE_COMPUTE_BUFFER_LOST, OUTPUT_COMPUTE_LOST, SENSOR_0,
#                        SENSOR_BUFFER_0, SENSOR_COMPUTE_0, SENSOR_COMPUTE_BUFFER_0,
#                        EDGE_COMPUTE_0, SENSOR_1, SENSOR_BUFFER_1, SENSOR_COMPUTE_1,
#                        SENSOR_COMPUTE_BUFFER_1, SENSOR_2, SENSOR_BUFFER_2,
#                        SENSOR_COMPUTE_2, SENSOR_COMPUTE_BUFFER_2, SENSOR_3,
#                        SENSOR_BUFFER_3, SENSOR_COMPUTE_3, SENSOR_COMPUTE_BUFFER_3,
#                        EDGE_COMPUTE_1, SENSOR_4, SENSOR_BUFFER_4, SENSOR_COMPUTE_4,
#                        SENSOR_COMPUTE_BUFFER_4, SENSOR_5, SENSOR_BUFFER_5,
#                        SENSOR_COMPUTE_5, SENSOR_COMPUTE_BUFFER_5, SENSOR_6,
#                        SENSOR_BUFFER_6, SENSOR_COMPUTE_6, SENSOR_COMPUTE_BUFFER_6,
#                        EDGE_COMPUTE_2, SENSOR_7, SENSOR_BUFFER_7, SENSOR_COMPUTE_7,
#                        SENSOR_COMPUTE_BUFFER_7, SENSOR_8, SENSOR_BUFFER_8,
#                        SENSOR_COMPUTE_8, SENSOR_COMPUTE_BUFFER_8, SENSOR_9,
#                        SENSOR_BUFFER_9, SENSOR_COMPUTE_9, SENSOR_COMPUTE_BUFFER_9,
#                        EDGE_COMPUTE_3, SENSOR_10, SENSOR_BUFFER_10,
#                        SENSOR_COMPUTE_10, SENSOR_COMPUTE_BUFFER_10,
#                        EDGE_COMPUTE_BUFFER_0, OUTPUT_COMPUTE,
#                        EDGE_COMPUTE_BUFFER_1, EDGE_COMPUTE_BUFFER_2,
#                        EDGE_COMPUTE_BUFFER_3, OUTPUT],
#               'textposition': 'top center',
#               'type': 'scatter',
#               'uid': 'a1b6086a-10ae-4554-9362-e0926d512333',
#               'x': [-0.06666666666666668, 0.11515151515151514, 0.296969696969697,
#                     0.4787878787878788, 0.6606060606060606, 0.8424242424242424,
#                     -0.4303030303030303, -0.2484848484848485, -0.06666666666666668,
#                     0.11515151515151514, 0.296969696969697, -0.4303030303030303,
#                     -0.2484848484848485, -0.06666666666666668, 0.11515151515151514,
#                     -0.4303030303030303, -0.2484848484848485, -0.06666666666666668,
#                     0.11515151515151514, -0.4303030303030303, -0.2484848484848485,
#                     -0.06666666666666668, 0.11515151515151514, 0.296969696969697,
#                     -0.4303030303030303, -0.2484848484848485, -0.06666666666666668,
#                     0.11515151515151514, -0.4303030303030303, -0.2484848484848485,
#                     -0.06666666666666668, 0.11515151515151514, -0.4303030303030303,
#                     -0.2484848484848485, -0.06666666666666668, 0.11515151515151514,
#                     0.296969696969697, -0.4303030303030303, -0.2484848484848485,
#                     -0.06666666666666668, 0.11515151515151514, -0.4303030303030303,
#                     -0.2484848484848485, -0.06666666666666668, 0.11515151515151514,
#                     -0.4303030303030303, -0.2484848484848485, -0.06666666666666668,
#                     0.11515151515151514, 0.296969696969697, -0.4303030303030303,
#                     -0.2484848484848485, -0.06666666666666668, 0.11515151515151514,
#                     0.4787878787878788, 0.6606060606060606, 0.4787878787878788,
#                     0.4787878787878788, 0.4787878787878788, 0.8424242424242424],
#               'y': [1.0, 1.0, 0.36363636363636365, 0.36363636363636365,
#                     0.09090909090909091, 0.09090909090909091, -0.9090909090909092,
#                     -0.9090909090909092, -1.0, -1.0, -0.36363636363636365,
#                     -0.7272727272727273, -0.7272727272727273, -0.8181818181818182,
#                     -0.8181818181818182, -0.5454545454545454, -0.5454545454545454,
#                     -0.6363636363636364, -0.6363636363636364, -0.36363636363636365,
#                     -0.36363636363636365, -0.4545454545454546, -0.4545454545454546,
#                     -0.18181818181818182, -0.18181818181818182,
#                     -0.18181818181818182, -0.2727272727272727, -0.2727272727272727,
#                     0.0, 0.0, -0.09090909090909091, -0.09090909090909091,
#                     0.18181818181818182, 0.18181818181818182, 0.09090909090909091,
#                     0.09090909090909091, 0.0, 0.36363636363636365,
#                     0.36363636363636365, 0.2727272727272727, 0.2727272727272727,
#                     0.5454545454545454, 0.5454545454545454, 0.4545454545454546,
#                     0.4545454545454546, 0.7272727272727273, 0.7272727272727273,
#                     0.6363636363636364, 0.6363636363636364, 0.18181818181818182,
#                     0.9090909090909092, 0.9090909090909092, 0.8181818181818182,
#                     0.8181818181818182, -0.36363636363636365, -0.09090909090909091,
#                     -0.18181818181818182, 0.0, 0.18181818181818182,
#                     -0.09090909090909091]}],
#     'layout': {'coloraxis': {'colorbar': {'thickness': 0, 'ticklen': 0}, 'showscale': False},
#                'hovermode': 'closest',
#                'margin': {'b': 20, 'l': 5, 'r': 5, 't': 40},
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 16}},
#                'xaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False},
#                'yaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False}}
# })
